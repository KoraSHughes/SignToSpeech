# %%
"""
Purpose: take in a video at a certain directory and product a series of images to be fed into the learning 
interval of video - hyperparameter
"""
# Out:
# '\nPurpose: take in a video at a certain directory and product a series of images to be fed into the learning \ninterval of video - hyperparameter\n'

# %%
import os
import cv2

# %%
vid_dir = "/src-videos/"  # existing folders
img_dir = "/test-images/"

def main():
    # get images
    cwd = os.getcwd()  # current dir
    videos = [cwd+vid_dir+file for file in os.listdir(cwd+vid_dir) if '.mov' in file]  # list of videos via dir string
    assert len(videos) >= 1
    print("Found videos...\n")
    
    # first letter of the file should be what category it is (used for the data processing in SignToSpeech file)
    # hyperparameter for what letter we are looking at (known as of vid recording)
    letters = [let[-10].upper() for let in videos]  # specific to name of video
    
    # check that videos line up with letters
    for j in range(len(videos)):
        print(videos[j][-11:], "=>", letters[j])
    
    # video pre-processing 
    fps = 3  # desired frames per second approximately
    i = 1  # count of videos
    print("\nProcessing videos...")
    for vid in videos:
        print("searching through video:", vid)
        image_name = "video" + str(i) + "-image"
        vidcap = cv2.VideoCapture(vid)  # init video
#         vidcap.set(cv2.CAP_PROP_FPS, fps)  # set frames
        rate = round(vidcap.get(cv2.CAP_PROP_FPS)/fps)  # actual fps/desired fps = rate of capture of our video
        success, image = vidcap.read()
        count = 0  # count of elapsed frames
        rate_count = 0  # count of pictures taken
        while success:
            if count == 0:
                print("processing images from video", i, "with", vidcap.get(cv2.CAP_PROP_FPS), "fps")
            if count%rate == 0:
                rate_count += 1
                cv2.imwrite((cwd+img_dir+letters[i-1]+image_name+str(rate_count)+".png"), image) # save frame as png file 
                print("frame", count, "saved into", (letters[i-1]+image_name+str(rate_count)+".png"))
            success, image = vidcap.read()
#           print('Read a new frame: ', success)
            count += 1
        print("Video", i, "returned", rate_count, "images from", count, "frames.")
        i += 1
        print()
        
    

if __name__ == "__main__":
    main()
    print("\n...done :)")
# Out:
# Found videos...
#
# /w-lisa.mov => W
# /y-kora.mov => Y
# /b-lisa.mov => B
# /h-lisa.mov => H
# /a-kora.mov => A
# /k-kora.mov => K
# /k-lisa.mov => K
# /a-lisa.mov => A
# /y-lisa.mov => Y
# /w-kora.mov => W
# /h-kora.mov => H
# /b-kora.mov => B
#
# Processing videos...
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/w-lisa.mov
# processing images from video 1 with 59.37313432835821 fps
# frame 0 saved into Wvideo1-image1.png
# frame 20 saved into Wvideo1-image2.png
# frame 40 saved into Wvideo1-image3.png
# frame 60 saved into Wvideo1-image4.png
# frame 80 saved into Wvideo1-image5.png
# frame 100 saved into Wvideo1-image6.png
# frame 120 saved into Wvideo1-image7.png
# frame 140 saved into Wvideo1-image8.png
# frame 160 saved into Wvideo1-image9.png
# frame 180 saved into Wvideo1-image10.png
# frame 200 saved into Wvideo1-image11.png
# frame 220 saved into Wvideo1-image12.png
# frame 240 saved into Wvideo1-image13.png
# frame 260 saved into Wvideo1-image14.png
# frame 280 saved into Wvideo1-image15.png
# frame 300 saved into Wvideo1-image16.png
# frame 320 saved into Wvideo1-image17.png
# frame 340 saved into Wvideo1-image18.png
# frame 360 saved into Wvideo1-image19.png
# frame 380 saved into Wvideo1-image20.png
# frame 400 saved into Wvideo1-image21.png
# frame 420 saved into Wvideo1-image22.png
# frame 440 saved into Wvideo1-image23.png
# frame 460 saved into Wvideo1-image24.png
# frame 480 saved into Wvideo1-image25.png
# frame 500 saved into Wvideo1-image26.png
# frame 520 saved into Wvideo1-image27.png
# frame 540 saved into Wvideo1-image28.png
# frame 560 saved into Wvideo1-image29.png
# frame 580 saved into Wvideo1-image30.png
# frame 600 saved into Wvideo1-image31.png
# frame 620 saved into Wvideo1-image32.png
# frame 640 saved into Wvideo1-image33.png
# Video 1 returned 33 images from 660 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/y-kora.mov
# processing images from video 2 with 59.3859649122807 fps
# frame 0 saved into Yvideo2-image1.png
# frame 20 saved into Yvideo2-image2.png
# frame 40 saved into Yvideo2-image3.png
# frame 60 saved into Yvideo2-image4.png
# frame 80 saved into Yvideo2-image5.png
# frame 100 saved into Yvideo2-image6.png
# frame 120 saved into Yvideo2-image7.png
# frame 140 saved into Yvideo2-image8.png
# frame 160 saved into Yvideo2-image9.png
# frame 180 saved into Yvideo2-image10.png
# frame 200 saved into Yvideo2-image11.png
# frame 220 saved into Yvideo2-image12.png
# frame 240 saved into Yvideo2-image13.png
# frame 260 saved into Yvideo2-image14.png
# frame 280 saved into Yvideo2-image15.png
# frame 300 saved into Yvideo2-image16.png
# frame 320 saved into Yvideo2-image17.png
# frame 340 saved into Yvideo2-image18.png
# frame 360 saved into Yvideo2-image19.png
# frame 380 saved into Yvideo2-image20.png
# frame 400 saved into Yvideo2-image21.png
# frame 420 saved into Yvideo2-image22.png
# frame 440 saved into Yvideo2-image23.png
# frame 460 saved into Yvideo2-image24.png
# frame 480 saved into Yvideo2-image25.png
# frame 500 saved into Yvideo2-image26.png
# frame 520 saved into Yvideo2-image27.png
# frame 540 saved into Yvideo2-image28.png
# frame 560 saved into Yvideo2-image29.png
# frame 580 saved into Yvideo2-image30.png
# frame 600 saved into Yvideo2-image31.png
# frame 620 saved into Yvideo2-image32.png
# frame 640 saved into Yvideo2-image33.png
# frame 660 saved into Yvideo2-image34.png
# Video 2 returned 34 images from 674 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/b-lisa.mov
# processing images from video 3 with 59.36555891238671 fps
# frame 0 saved into Bvideo3-image1.png
# frame 20 saved into Bvideo3-image2.png
# frame 40 saved into Bvideo3-image3.png
# frame 60 saved into Bvideo3-image4.png
# frame 80 saved into Bvideo3-image5.png
# frame 100 saved into Bvideo3-image6.png
# frame 120 saved into Bvideo3-image7.png
# frame 140 saved into Bvideo3-image8.png
# frame 160 saved into Bvideo3-image9.png
# frame 180 saved into Bvideo3-image10.png
# frame 200 saved into Bvideo3-image11.png
# frame 220 saved into Bvideo3-image12.png
# frame 240 saved into Bvideo3-image13.png
# frame 260 saved into Bvideo3-image14.png
# frame 280 saved into Bvideo3-image15.png
# frame 300 saved into Bvideo3-image16.png
# frame 320 saved into Bvideo3-image17.png
# frame 340 saved into Bvideo3-image18.png
# frame 360 saved into Bvideo3-image19.png
# frame 380 saved into Bvideo3-image20.png
# frame 400 saved into Bvideo3-image21.png
# frame 420 saved into Bvideo3-image22.png
# frame 440 saved into Bvideo3-image23.png
# frame 460 saved into Bvideo3-image24.png
# frame 480 saved into Bvideo3-image25.png
# frame 500 saved into Bvideo3-image26.png
# frame 520 saved into Bvideo3-image27.png
# frame 540 saved into Bvideo3-image28.png
# frame 560 saved into Bvideo3-image29.png
# frame 580 saved into Bvideo3-image30.png
# frame 600 saved into Bvideo3-image31.png
# frame 620 saved into Bvideo3-image32.png
# frame 640 saved into Bvideo3-image33.png
# Video 3 returned 33 images from 652 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/h-lisa.mov
# processing images from video 4 with 59.26040061633282 fps
# frame 0 saved into Hvideo4-image1.png
# frame 20 saved into Hvideo4-image2.png
# frame 40 saved into Hvideo4-image3.png
# frame 60 saved into Hvideo4-image4.png
# frame 80 saved into Hvideo4-image5.png
# frame 100 saved into Hvideo4-image6.png
# frame 120 saved into Hvideo4-image7.png
# frame 140 saved into Hvideo4-image8.png
# frame 160 saved into Hvideo4-image9.png
# frame 180 saved into Hvideo4-image10.png
# frame 200 saved into Hvideo4-image11.png
# frame 220 saved into Hvideo4-image12.png
# frame 240 saved into Hvideo4-image13.png
# frame 260 saved into Hvideo4-image14.png
# frame 280 saved into Hvideo4-image15.png
# frame 300 saved into Hvideo4-image16.png
# frame 320 saved into Hvideo4-image17.png
# frame 340 saved into Hvideo4-image18.png
# frame 360 saved into Hvideo4-image19.png
# frame 380 saved into Hvideo4-image20.png
# frame 400 saved into Hvideo4-image21.png
# frame 420 saved into Hvideo4-image22.png
# frame 440 saved into Hvideo4-image23.png
# frame 460 saved into Hvideo4-image24.png
# frame 480 saved into Hvideo4-image25.png
# frame 500 saved into Hvideo4-image26.png
# frame 520 saved into Hvideo4-image27.png
# frame 540 saved into Hvideo4-image28.png
# frame 560 saved into Hvideo4-image29.png
# frame 580 saved into Hvideo4-image30.png
# frame 600 saved into Hvideo4-image31.png
# frame 620 saved into Hvideo4-image32.png
# Video 4 returned 32 images from 638 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/a-kora.mov
# processing images from video 5 with 57.142857142857146 fps
# frame 0 saved into Avideo5-image1.png
# frame 19 saved into Avideo5-image2.png
# frame 38 saved into Avideo5-image3.png
# frame 57 saved into Avideo5-image4.png
# frame 76 saved into Avideo5-image5.png
# frame 95 saved into Avideo5-image6.png
# frame 114 saved into Avideo5-image7.png
# frame 133 saved into Avideo5-image8.png
# frame 152 saved into Avideo5-image9.png
# frame 171 saved into Avideo5-image10.png
# frame 190 saved into Avideo5-image11.png
# frame 209 saved into Avideo5-image12.png
# frame 228 saved into Avideo5-image13.png
# frame 247 saved into Avideo5-image14.png
# frame 266 saved into Avideo5-image15.png
# frame 285 saved into Avideo5-image16.png
# frame 304 saved into Avideo5-image17.png
# frame 323 saved into Avideo5-image18.png
# frame 342 saved into Avideo5-image19.png
# frame 361 saved into Avideo5-image20.png
# frame 380 saved into Avideo5-image21.png
# frame 399 saved into Avideo5-image22.png
# frame 418 saved into Avideo5-image23.png
# frame 437 saved into Avideo5-image24.png
# frame 456 saved into Avideo5-image25.png
# frame 475 saved into Avideo5-image26.png
# frame 494 saved into Avideo5-image27.png
# frame 513 saved into Avideo5-image28.png
# frame 532 saved into Avideo5-image29.png
# frame 551 saved into Avideo5-image30.png
# frame 570 saved into Avideo5-image31.png
# frame 589 saved into Avideo5-image32.png
# Video 5 returned 32 images from 598 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/k-kora.mov
# processing images from video 6 with 59.64125560538117 fps
# frame 0 saved into Kvideo6-image1.png
# frame 20 saved into Kvideo6-image2.png
# frame 40 saved into Kvideo6-image3.png
# frame 60 saved into Kvideo6-image4.png
# frame 80 saved into Kvideo6-image5.png
# frame 100 saved into Kvideo6-image6.png
# frame 120 saved into Kvideo6-image7.png
# frame 140 saved into Kvideo6-image8.png
# frame 160 saved into Kvideo6-image9.png
# frame 180 saved into Kvideo6-image10.png
# frame 200 saved into Kvideo6-image11.png
# frame 220 saved into Kvideo6-image12.png
# frame 240 saved into Kvideo6-image13.png
# frame 260 saved into Kvideo6-image14.png
# frame 280 saved into Kvideo6-image15.png
# frame 300 saved into Kvideo6-image16.png
# frame 320 saved into Kvideo6-image17.png
# frame 340 saved into Kvideo6-image18.png
# frame 360 saved into Kvideo6-image19.png
# frame 380 saved into Kvideo6-image20.png
# frame 400 saved into Kvideo6-image21.png
# frame 420 saved into Kvideo6-image22.png
# frame 440 saved into Kvideo6-image23.png
# frame 460 saved into Kvideo6-image24.png
# frame 480 saved into Kvideo6-image25.png
# frame 500 saved into Kvideo6-image26.png
# frame 520 saved into Kvideo6-image27.png
# frame 540 saved into Kvideo6-image28.png
# frame 560 saved into Kvideo6-image29.png
# frame 580 saved into Kvideo6-image30.png
# frame 600 saved into Kvideo6-image31.png
# frame 620 saved into Kvideo6-image32.png
# frame 640 saved into Kvideo6-image33.png
# frame 660 saved into Kvideo6-image34.png
# Video 6 returned 34 images from 662 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/k-lisa.mov
# processing images from video 7 with 59.329073482428115 fps
# frame 0 saved into Kvideo7-image1.png
# frame 20 saved into Kvideo7-image2.png
# frame 40 saved into Kvideo7-image3.png
# frame 60 saved into Kvideo7-image4.png
# frame 80 saved into Kvideo7-image5.png
# frame 100 saved into Kvideo7-image6.png
# frame 120 saved into Kvideo7-image7.png
# frame 140 saved into Kvideo7-image8.png
# frame 160 saved into Kvideo7-image9.png
# frame 180 saved into Kvideo7-image10.png
# frame 200 saved into Kvideo7-image11.png
# frame 220 saved into Kvideo7-image12.png
# frame 240 saved into Kvideo7-image13.png
# frame 260 saved into Kvideo7-image14.png
# frame 280 saved into Kvideo7-image15.png
# frame 300 saved into Kvideo7-image16.png
# frame 320 saved into Kvideo7-image17.png
# frame 340 saved into Kvideo7-image18.png
# frame 360 saved into Kvideo7-image19.png
# frame 380 saved into Kvideo7-image20.png
# frame 400 saved into Kvideo7-image21.png
# frame 420 saved into Kvideo7-image22.png
# frame 440 saved into Kvideo7-image23.png
# frame 460 saved into Kvideo7-image24.png
# frame 480 saved into Kvideo7-image25.png
# frame 500 saved into Kvideo7-image26.png
# frame 520 saved into Kvideo7-image27.png
# frame 540 saved into Kvideo7-image28.png
# frame 560 saved into Kvideo7-image29.png
# frame 580 saved into Kvideo7-image30.png
# frame 600 saved into Kvideo7-image31.png
# Video 7 returned 31 images from 616 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/a-lisa.mov
# processing images from video 8 with 59.56395348837209 fps
# frame 0 saved into Avideo8-image1.png
# frame 20 saved into Avideo8-image2.png
# frame 40 saved into Avideo8-image3.png
# frame 60 saved into Avideo8-image4.png
# frame 80 saved into Avideo8-image5.png
# frame 100 saved into Avideo8-image6.png
# frame 120 saved into Avideo8-image7.png
# frame 140 saved into Avideo8-image8.png
# frame 160 saved into Avideo8-image9.png
# frame 180 saved into Avideo8-image10.png
# frame 200 saved into Avideo8-image11.png
# frame 220 saved into Avideo8-image12.png
# frame 240 saved into Avideo8-image13.png
# frame 260 saved into Avideo8-image14.png
# frame 280 saved into Avideo8-image15.png
# frame 300 saved into Avideo8-image16.png
# frame 320 saved into Avideo8-image17.png
# frame 340 saved into Avideo8-image18.png
# frame 360 saved into Avideo8-image19.png
# frame 380 saved into Avideo8-image20.png
# frame 400 saved into Avideo8-image21.png
# frame 420 saved into Avideo8-image22.png
# frame 440 saved into Avideo8-image23.png
# frame 460 saved into Avideo8-image24.png
# frame 480 saved into Avideo8-image25.png
# frame 500 saved into Avideo8-image26.png
# frame 520 saved into Avideo8-image27.png
# frame 540 saved into Avideo8-image28.png
# frame 560 saved into Avideo8-image29.png
# frame 580 saved into Avideo8-image30.png
# frame 600 saved into Avideo8-image31.png
# frame 620 saved into Avideo8-image32.png
# frame 640 saved into Avideo8-image33.png
# frame 660 saved into Avideo8-image34.png
# Video 8 returned 34 images from 680 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/y-lisa.mov
# processing images from video 9 with 59.369369369369366 fps
# frame 0 saved into Yvideo9-image1.png
# frame 20 saved into Yvideo9-image2.png
# frame 40 saved into Yvideo9-image3.png
# frame 60 saved into Yvideo9-image4.png
# frame 80 saved into Yvideo9-image5.png
# frame 100 saved into Yvideo9-image6.png
# frame 120 saved into Yvideo9-image7.png
# frame 140 saved into Yvideo9-image8.png
# frame 160 saved into Yvideo9-image9.png
# frame 180 saved into Yvideo9-image10.png
# frame 200 saved into Yvideo9-image11.png
# frame 220 saved into Yvideo9-image12.png
# frame 240 saved into Yvideo9-image13.png
# frame 260 saved into Yvideo9-image14.png
# frame 280 saved into Yvideo9-image15.png
# frame 300 saved into Yvideo9-image16.png
# frame 320 saved into Yvideo9-image17.png
# frame 340 saved into Yvideo9-image18.png
# frame 360 saved into Yvideo9-image19.png
# frame 380 saved into Yvideo9-image20.png
# frame 400 saved into Yvideo9-image21.png
# frame 420 saved into Yvideo9-image22.png
# frame 440 saved into Yvideo9-image23.png
# frame 460 saved into Yvideo9-image24.png
# frame 480 saved into Yvideo9-image25.png
# frame 500 saved into Yvideo9-image26.png
# frame 520 saved into Yvideo9-image27.png
# frame 540 saved into Yvideo9-image28.png
# frame 560 saved into Yvideo9-image29.png
# frame 580 saved into Yvideo9-image30.png
# frame 600 saved into Yvideo9-image31.png
# frame 620 saved into Yvideo9-image32.png
# frame 640 saved into Yvideo9-image33.png
# Video 9 returned 33 images from 656 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/w-kora.mov
# processing images from video 10 with 59.39306358381503 fps
# frame 0 saved into Wvideo10-image1.png
# frame 20 saved into Wvideo10-image2.png
# frame 40 saved into Wvideo10-image3.png
# frame 60 saved into Wvideo10-image4.png
# frame 80 saved into Wvideo10-image5.png
# frame 100 saved into Wvideo10-image6.png
# frame 120 saved into Wvideo10-image7.png
# frame 140 saved into Wvideo10-image8.png
# frame 160 saved into Wvideo10-image9.png
# frame 180 saved into Wvideo10-image10.png
# frame 200 saved into Wvideo10-image11.png
# frame 220 saved into Wvideo10-image12.png
# frame 240 saved into Wvideo10-image13.png
# frame 260 saved into Wvideo10-image14.png
# frame 280 saved into Wvideo10-image15.png
# frame 300 saved into Wvideo10-image16.png
# frame 320 saved into Wvideo10-image17.png
# frame 340 saved into Wvideo10-image18.png
# frame 360 saved into Wvideo10-image19.png
# frame 380 saved into Wvideo10-image20.png
# frame 400 saved into Wvideo10-image21.png
# frame 420 saved into Wvideo10-image22.png
# frame 440 saved into Wvideo10-image23.png
# frame 460 saved into Wvideo10-image24.png
# frame 480 saved into Wvideo10-image25.png
# frame 500 saved into Wvideo10-image26.png
# frame 520 saved into Wvideo10-image27.png
# frame 540 saved into Wvideo10-image28.png
# frame 560 saved into Wvideo10-image29.png
# frame 580 saved into Wvideo10-image30.png
# frame 600 saved into Wvideo10-image31.png
# frame 620 saved into Wvideo10-image32.png
# frame 640 saved into Wvideo10-image33.png
# frame 660 saved into Wvideo10-image34.png
# frame 680 saved into Wvideo10-image35.png
# Video 10 returned 35 images from 682 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/h-kora.mov
# processing images from video 11 with 59.375 fps
# frame 0 saved into Hvideo11-image1.png
# frame 20 saved into Hvideo11-image2.png
# frame 40 saved into Hvideo11-image3.png
# frame 60 saved into Hvideo11-image4.png
# frame 80 saved into Hvideo11-image5.png
# frame 100 saved into Hvideo11-image6.png
# frame 120 saved into Hvideo11-image7.png
# frame 140 saved into Hvideo11-image8.png
# frame 160 saved into Hvideo11-image9.png
# frame 180 saved into Hvideo11-image10.png
# frame 200 saved into Hvideo11-image11.png
# frame 220 saved into Hvideo11-image12.png
# frame 240 saved into Hvideo11-image13.png
# frame 260 saved into Hvideo11-image14.png
# frame 280 saved into Hvideo11-image15.png
# frame 300 saved into Hvideo11-image16.png
# frame 320 saved into Hvideo11-image17.png
# frame 340 saved into Hvideo11-image18.png
# frame 360 saved into Hvideo11-image19.png
# frame 380 saved into Hvideo11-image20.png
# frame 400 saved into Hvideo11-image21.png
# frame 420 saved into Hvideo11-image22.png
# frame 440 saved into Hvideo11-image23.png
# frame 460 saved into Hvideo11-image24.png
# frame 480 saved into Hvideo11-image25.png
# frame 500 saved into Hvideo11-image26.png
# frame 520 saved into Hvideo11-image27.png
# frame 540 saved into Hvideo11-image28.png
# frame 560 saved into Hvideo11-image29.png
# frame 580 saved into Hvideo11-image30.png
# frame 600 saved into Hvideo11-image31.png
# frame 620 saved into Hvideo11-image32.png
# frame 640 saved into Hvideo11-image33.png
# frame 660 saved into Hvideo11-image34.png
# Video 11 returned 34 images from 662 frames.
#
# searching through video: /Users/korahughes/Documents/GitHub/SignToSpeech/src-videos/b-kora.mov
# processing images from video 12 with 59.375 fps
# frame 0 saved into Bvideo12-image1.png
# frame 20 saved into Bvideo12-image2.png
# frame 40 saved into Bvideo12-image3.png
# frame 60 saved into Bvideo12-image4.png
# frame 80 saved into Bvideo12-image5.png
# frame 100 saved into Bvideo12-image6.png
# frame 120 saved into Bvideo12-image7.png
# frame 140 saved into Bvideo12-image8.png
# frame 160 saved into Bvideo12-image9.png
# frame 180 saved into Bvideo12-image10.png
# frame 200 saved into Bvideo12-image11.png
# frame 220 saved into Bvideo12-image12.png
# frame 240 saved into Bvideo12-image13.png
# frame 260 saved into Bvideo12-image14.png
# frame 280 saved into Bvideo12-image15.png
# frame 300 saved into Bvideo12-image16.png
# frame 320 saved into Bvideo12-image17.png
# frame 340 saved into Bvideo12-image18.png
# frame 360 saved into Bvideo12-image19.png
# frame 380 saved into Bvideo12-image20.png
# frame 400 saved into Bvideo12-image21.png
# frame 420 saved into Bvideo12-image22.png
# frame 440 saved into Bvideo12-image23.png
# frame 460 saved into Bvideo12-image24.png
# frame 480 saved into Bvideo12-image25.png
# frame 500 saved into Bvideo12-image26.png
# frame 520 saved into Bvideo12-image27.png
# frame 540 saved into Bvideo12-image28.png
# frame 560 saved into Bvideo12-image29.png
# frame 580 saved into Bvideo12-image30.png
# frame 600 saved into Bvideo12-image31.png
# frame 620 saved into Bvideo12-image32.png
# frame 640 saved into Bvideo12-image33.png
# frame 660 saved into Bvideo12-image34.png
# Video 12 returned 34 images from 662 frames.
#
#
# ...done :)
